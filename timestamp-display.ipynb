# %%
from youtube_transcript_api import YouTubeTranscriptApi
import urllib.request
import json
import urllib

# %%
VideoID = 'OmS94lV-X6o'

# %%
params = {"format": "json", "url": "https://www.youtube.com/watch?v=%s" % VideoID}
url = "https://www.youtube.com/oembed"
query_string = urllib.parse.urlencode(params)
url = url + "?" + query_string

with urllib.request.urlopen(url) as response:
    response_text = response.read()
    data = json.loads(response_text.decode())
    print('Titel: ' + data['title'])
    

print(' ')


# retrieve the available transcripts
transcript_list = YouTubeTranscriptApi.list_transcripts(VideoID)

# iterate over all available transcripts
for transcript in transcript_list:

    # fetch the actual transcript data
    print(transcript.fetch())
    data = transcript.fetch()
    
# you can also directly filter for the language you are looking for, using the transcript list
transcript = transcript_list.find_transcript(['en'])  
# print(data)
# Out:
# Titel: Why Mark Zuckerberg Is The G.O.A.T.
#
# [{'text': 'but 21-year-old Mark Zuckerberg turned', 'start': 0.04, 'duration': 5.16}, {'text': 'his little web experiment into a very', 'start': 2.84, 'duration': 4.4}, {'text': 'big business I view our responsibility', 'start': 5.2, 'duration': 3.519}, {'text': 'as not just Building Services that', 'start': 7.24, 'duration': 3.12}, {'text': 'people like but Building Services that', 'start': 8.719, 'duration': 3.721}, {'text': 'are good for people and good for Society', 'start': 10.36, 'duration': 4.76}, {'text': 'Facebook has squashed potential threats', 'start': 12.44, 'duration': 5.12}, {'text': "you've got families whose children are", 'start': 15.12, 'duration': 4.6}, {'text': 'either severely harmed or gone there', 'start': 17.56, 'duration': 4.32}, {'text': 'another major setback for Facebook still', 'start': 19.72, 'duration': 3.96}, {'text': 'no word from Mark Zuckerberg in the', 'start': 21.88, 'duration': 4.08}, {'text': 'Facebook Cambridge analytica Scandal let', 'start': 23.68, 'duration': 3.56}, {'text': "me ask you this there's families of", 'start': 25.96, 'duration': 3.0}, {'text': 'victims here today have you apologized', 'start': 27.24, 'duration': 3.999}, {'text': 'to the victims would you to do so now Mr', 'start': 28.96, 'duration': 5.279}, {'text': 'Zuckerberg why should your company not', 'start': 31.239, 'duration': 5.561}, {'text': 'be sued for', 'start': 34.239, 'duration': 12.0}, {'text': '[Music]', 'start': 36.8, 'duration': 12.079}, {'text': 'this for a long time the prevailing', 'start': 46.239, 'duration': 4.8}, {'text': "narrative about Zuckerberg was that he's", 'start': 48.879, 'duration': 4.241}, {'text': "a robot and doesn't have emotions and", 'start': 51.039, 'duration': 4.04}, {'text': 'steals your data this past year', 'start': 53.12, 'duration': 3.88}, {'text': 'especially has been quite eventful for', 'start': 55.079, 'duration': 4.081}, {'text': 'Mark Zuckerberg he created Facebook as', 'start': 57.0, 'duration': 3.559}, {'text': 'you all know which is is now known as', 'start': 59.16, 'duration': 4.199}, {'text': 'meta a huge company in social media but', 'start': 60.559, 'duration': 5.121}, {'text': 'a year ago even the people who invested', 'start': 63.359, 'duration': 4.721}, {'text': 'in his company were upset with him they', 'start': 65.68, 'duration': 4.479}, {'text': 'thought he was ruining the main part of', 'start': 68.08, 'duration': 4.48}, {'text': 'his social media business by spending', 'start': 70.159, 'duration': 4.921}, {'text': 'too much money on creating the metaverse', 'start': 72.56, 'duration': 4.919}, {'text': 'a digital world that at that time seemed', 'start': 75.08, 'duration': 4.6}, {'text': 'like a fantasy to many when meta', 'start': 77.479, 'duration': 4.161}, {'text': "announced it wasn't making as much money", 'start': 79.68, 'duration': 3.6}, {'text': "as expected in last year's earnings", 'start': 81.64, 'duration': 3.479}, {'text': 'report its stock value dropped', 'start': 83.28, 'duration': 3.839}, {'text': 'significantly and people were very', 'start': 85.119, 'duration': 4.04}, {'text': "disappointed in Zuckerberg that's when", 'start': 87.119, 'duration': 4.04}, {'text': 'the narrative for Zuckerberg had reached', 'start': 89.159, 'duration': 4.32}, {'text': 'its lowest however things had turned', 'start': 91.159, 'duration': 4.24}, {'text': 'around in the past year meta which', 'start': 93.479, 'duration': 4.121}, {'text': 'connects 3.1 billion people daily', 'start': 95.399, 'duration': 4.561}, {'text': 'through Facebook Instagram and WhatsApp', 'start': 97.6, 'duration': 4.72}, {'text': 'and makes money by selling ads is now', 'start': 99.96, 'duration': 5.28}, {'text': 'doing much much better on October 25th', 'start': 102.32, 'duration': 5.439}, {'text': 'the company said it had made $ 34.1', 'start': 105.24, 'duration': 6.239}, {'text': 'billion in just 3 months which is 23%', 'start': 107.759, 'duration': 6.68}, {'text': 'more than the s ...

# %%
user_input = input("Enter a word or sentence: ")
user_input = user_input.lower()

dictionary = data

def search_dictionary(user_input, dictionary):
    
    link = 'https://youtu.be/'

    for i in dictionary:
        i['text'] = i['text'].lower()


    for i in dictionary:

        try:
            if user_input in i['text']:
                
                for i in dictionary:
                    if user_input in i['text']:
                        
                        #I added -1 seconds to give the user a little more time 
                        print(str(i['text']) + '...' + ' ' + str( round(i['start'] // 60, 2)) + ' min' + ' und ' + str( round(i['start'] % 60, 0)) + ' sec' + ' ' + ':: ' + link + VideoID + '?t=' + str(int(i['start'] - 1)) + 's')
            
                break
            
        except:
            if user_input not in i['text']:
              print('Not Found')
  
    



search_dictionary(user_input, dictionary)
# Out:
# but 21-year-old mark zuckerberg turned... 0.0 min und 0.0 sec :: https://youtu.be/OmS94lV-X6o?t=0s
# no word from mark zuckerberg in the... 0.0 min und 22.0 sec :: https://youtu.be/OmS94lV-X6o?t=20s
# mark zuckerberg he created facebook as... 0.0 min und 57.0 sec :: https://youtu.be/OmS94lV-X6o?t=56s
# got killed in the stock market was... 3.0 min und 11.0 sec :: https://youtu.be/OmS94lV-X6o?t=189s
# first look to mark zuckerberg sitting in... 3.0 min und 38.0 sec :: https://youtu.be/OmS94lV-X6o?t=217s
# argument that mark zuckerberg is some... 5.0 min und 33.0 sec :: https://youtu.be/OmS94lV-X6o?t=331s
# mature and i think mark ss had so many... 6.0 min und 27.0 sec :: https://youtu.be/OmS94lV-X6o?t=385s
# facebook was a bad company and mark... 12.0 min und 34.0 sec :: https://youtu.be/OmS94lV-X6o?t=753s
# long time no matter what mark zuckerberg... 13.0 min und 50.0 sec :: https://youtu.be/OmS94lV-X6o?t=828s
# long time mark zuckerberg has been the... 14.0 min und 24.0 sec :: https://youtu.be/OmS94lV-X6o?t=862s
# resurrection of mark zuckerberg because... 17.0 min und 5.0 sec :: https://youtu.be/OmS94lV-X6o?t=1024s
# in the market as a really bad move... 18.0 min und 50.0 sec :: https://youtu.be/OmS94lV-X6o?t=1128s
# for mark zuckerberg he's playing one of... 20.0 min und 34.0 sec :: https://youtu.be/OmS94lV-X6o?t=1233s
# piece of themselves inside mark... 20.0 min und 50.0 sec :: https://youtu.be/OmS94lV-X6o?t=1249s

# %%
import streamlit as st
import re

def extract_start_time(video_url):
    match = re.search(r'\?t=(\d+)s', video_url)
    if match:
        return int(match.group(1))
    else:
        return 0  # Default to start from the beginning if time parameter not found

VIDEO_URL = "https://youtu.be/OmS94lV-X6o?t=124s"
start_time = extract_start_time(VIDEO_URL)

st.video(VIDEO_URL, start_time=start_time)
# Out:
# 2024-04-10 22:43:18.541
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run d:\CODESPACES\Hackathons\Learner's Video - Analyser\venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()
